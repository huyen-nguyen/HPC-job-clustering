# %%
import pandas as pd

df = pd.read_csv("data.csv", parse_dates=True)

# %%
df
# Out:
#         Unnamed: 0                                 _id   qname  \
# 0                0  ObjectId(5f24fe11c14d4f44f577352e)    omni
# 1                1  ObjectId(5f24fe11c14d4f44f577352f)    omni
# 2                2  ObjectId(5f24fe11c14d4f44f577352a)    omni
# 3                3  ObjectId(5f24fe11c14d4f44f577352b)    omni
# 4                4  ObjectId(5f24fe11c14d4f44f577352c)    omni
# ...            ...                                 ...     ...
# 457481      457481  ObjectId(5f804788c14d4f0ff4b52a77)  Chewie
# 457482      457482  ObjectId(5f820988c14d4f0ff4b93ce6)  Chewie
# 457483      457483  ObjectId(5f819909c14d4f0ff4b83f17)  Chewie
# 457484      457484  ObjectId(5f83af6ac14d4f0ff4bd2c85)    omni
# 457485      457485  ObjectId(5f82f898c14d4f0ff4bb5aed)    omni
#
#                          hostname    group     owner        job_name  \
# 0        compute-4-29.localdomain     phys   msanati    MPI_Test_Job
# ...
