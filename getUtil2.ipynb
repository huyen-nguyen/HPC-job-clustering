# %%
import os
import glob
import pandas as pd
os.chdir("SelectedJobs")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-f9524811643d> in <module>
#       2 import glob
#       3 import pandas as pd
# ----> 4 os.chdir("SelectedJobs")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'SelectedJobs'

# %% [markdown]
# ### merge to one csv

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ### run

# %%
df = pd.read_csv("combined.csv", parse_dates=True)

# %%
df['slots'].min()
# Out:
# 1.0

# %%
df['owner'].value_counts()
# Out:
# ruiqliu     11565
# aosmansk     7711
# dmorenos     7418
# juandomi     5800
# twixtrom     4197
#             ...
# acozzoli        1
# atindsin        1
# cristmor        1
# crock           1
# hsihaloh        1
# Name: owner, Length: 223, dtype: int64

# %%
df['job_id'].value_counts()
# Out:
# 1968127    1
# 1903348    1
# 1960680    1
# 1964778    1
# 1962731    1
#           ..
# 1920323    1
# 1930564    1
# 1932613    1
# 1926470    1
# 1966080    1
# Name: job_id, Length: 81101, dtype: int64

# %%
list(df.columns)
# Out:
# ['job_id',
#  'owner',
#  'job_name',
#  'group',
#  'department',
#  'granted_pe',
#  'cluster_name',
#  'qname',
#  'hostname',
#  'submission_epoch',
#  'start_epoch',
#  'end_epoch',
#  'wallclock',
#  'cpu',
#  'mem',
#  'io',
#  'iow',
#  'maxvmem',
#  'slots',
#  'task_number',
#  'pe_taskid',
#  'wait_time_seconds',
#  'failed',
#  'exit_status']

# %%
df['submission_epoch'].min()
# Out:
# 1593561860.0

# %%
df['submission_epoch'].max()
# Out:
# 1601509434.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# thruput (jobs/h)

81101/2208
# Out:
# 36.73052536231884
